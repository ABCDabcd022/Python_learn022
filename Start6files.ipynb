# %%
import os

# %%
for i in os.walk('C:\\PLACE\FILES\python_training_examples\learn'):
    print(i)
# Out:
# ('C:\\PLACE\\FILES\\python_training_examples\\learn', ['learn1', 'learn2'], ['text.txt'])
# ('C:\\PLACE\\FILES\\python_training_examples\\learn\\learn1', ['learn12'], ['text2.txt'])
# ('C:\\PLACE\\FILES\\python_training_examples\\learn\\learn1\\learn12', [], [])
# ('C:\\PLACE\\FILES\\python_training_examples\\learn\\learn2', [], [])

# %% [markdown]
# 'r' открыть для чтения (по умолчанию)
# 't' открыть в текстовом режиме (по умолчанию)
# 'w' открыть для записи, старое содержимое удаляется, если такого файла нет, создаётся новый
# 'a' открыть для записи в конец файла, если такого файла нет, создаётся новый
# 'b' открыть в бинарном режиме
# '+' открыть для чтения и записи

# %%
r = open('C:\\PLACE\\FILES\\python_training_examples\\learn\\text.txt', 'w')

# %%
r.write("Строка текста" + '\n')
r.write("Строка текста" + '\n')
# Out:
# 14

# %%
r.close()

# %%
r = open('C:\\PLACE\\FILES\\python_training_examples\\learn\\text.txt')
u = r.read()
print(u)
r.close()
# Out:
# Строка текста
# Строка текста

# %%
r = open('C:\\PLACE\\FILES\\python_training_examples\\learn\\text.txt')
u = r.read()
for i in u:
    print(i)
r.close()
# Out:
# С
# т
# р
# о
# к
# а
#
# т
# е
# к
# с
# т
# а
#
#
# С
# т
# р
# о
# к
# а
#
# т
# е
# к
# с
# т
# а

# %%
r = open('C:\\VKPlayLoader_2f81ce2793ac6c64235c6dd36e3189ea.exe')

r.close()

# %%
r = open('C:\\VKPlayLoader_2f81ce2793ac6c64235c6dd36e3189ea.exe', 'rb')
y = open('Копия VKPlayLoader_2f81ce2793ac6c64235c6dd36e3189ea.exe', 'wb')

while True:
    var = r.read(1048576) #байт
    print(var.__sizeof__())
    y.write(var)
    if var.__sizeof__() == 17:
        break
print("control")
    
r.close()
y.close()
# Out:
# 1048609
# 1048609
# 1048609
# 1048609
# 1048609
# 1048609
# 1048609
# 1048609
# 1048609
# 1048609
# 1048609
# 1048609
# 590537
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# ...

# %%
r = open('C:\\PLACE\\FILES\\python_training_examples\\learn\\text.txt', encoding = 'utf-8') #кодировка, и на запись
